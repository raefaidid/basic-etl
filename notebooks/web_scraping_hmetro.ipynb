# %% [markdown]
# # Phase 1: Get the list of articles

# %%
import pandas as pd
import requests
# Out:
# /Users/Raef/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/Raef/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
#169 - utama, 167 - mutakhir
# keys: 'nid', 'title', 'created', 'changed', 'sponsored', 'status', 'url', 'internal_url', 'emotion', 'segment', 'sentiment', 'field_force_ads', 'field_article_author', 'field_author_email', 'field_article_authors', 'field_article_topic', 'field_tags', 'field_article_images', 'field_article_images_filtered', 'field_article_videos', 'field_image_listing_featured_v2', 'field_image_listing_v2', 'field_image_socialmedia', 'field_image_slider', 'field_image_variasi', 'field_image_listing_featured', 'field_image_listing_th', 'field_image_th', 'field_article_state', 'field_article_lead', 'body', 'body_with_inline', 'word_count'
pd.set_option('display.max_colwidth', None)

lst_articles = []

for i in range(10):
    response = requests.get(f"https://www.hmetro.com.my/api/topics/169?page={i}")
    data = response.json()
    lst_articles.extend(data)

dataset = []

for index, item in enumerate(lst_articles):
    
    
    observations = {}
    observations['title'] = item['title']
    observations['url'] = item['url']
    try:
        observations['author_name'] = item['field_article_author']["name"]
    except:
        observations['author_name'] = None
    observations['word_count'] = item['word_count']

    dataset.append(observations)

df = pd.DataFrame(dataset)
display(df)
display(df.info())
# Out:
#                                                                         title  \
# 0           'Isteri dan emak sudah nyawa-nyawa ikan ketika cuba diselamatkan'
# 1                                    'Bukan cari hantu, bongkar lokasi keras'
# 2                                                Penglipur lara cerita seram!
# 3                 Tang Jie-Ee Wei cipta sejarah peribadi, juara Terbuka Korea
# 4                                            Membesar dengan lagu Raja Gambus
# ..                                                                        ...
# 195  Suspek tikam dua wanita di tandas surau di Kelana Jaya ditahan di Kajang
# 196                                          Hasil gubahan pencipta tiga kaum
# 197                                                    Cabaran 'Ustaz Jazlan'
# 198                                  Lelaki didakwa bunuh anak tauke restoran
# 199       Suspek bukan bekas teman lelaki arwah - suami Allahyarham Istiqomah
#
# ...

# %%
df.to_csv("../data/hmetro_articles_without_body.csv", index=False)

# %% [markdown]
# # Phase 2: Get the body of the article
#
# https://www.hmetro.com.my/utama/2024/09/1129405/isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatkan

# %%
article_url = "https://www.hmetro.com.my/utama/2024/09/1129405/isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatkan"

response = requests.get(article_url)
print(response.text)
# Out:
# <!--  -->
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <script src="https://www.googleoptimize.com/optimize.js?id=OPT-NQJ4GQK"></script>
# <link rel="dns-prefetch" href="https://ad.crwdcntrl.net" crossorigin>
# <link rel="dns-prefetch" href="https//www.googletagservices.com" crossorigin>
# <link rel="dns-prefetch" href="https//www.googletagmanager.com" crossorigin>
# <link rel="dns-prefetch" href="https://fonts.googleapis.com" crossorigin>
# <link rel="preconnect" href="https://tags.crwdcntrl.net">
# <link rel="preconnect" href="https://bcp.crwdcntrl.net">
# <link rel="dns-prefetch" href="https://tags.crwdcntrl.net">
# <link rel="dns-prefetch" href="https://bcp.crwdcntrl.net">
# <link rel="preload" href="https://assets.hmetro.com.my/assets/css/libraries.css?id=7979572225756f8aee4c" as="style">
# <link rel="preload" href="https://assets.hmetro.com.my/assets/css/desktop/app.css?id=e376b753c5b2f5388b00" as="style">
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!-- -->
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script src="https://www.googleoptimize.com/optimize.js?id=OPT-NQJ4GQK">
#   </script>
#   <link crossorigin="" href="https://ad.crwdcntrl.net" rel="dns-prefetch"/>
#   <link crossorigin="" href="https//www.googletagservices.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https//www.googletagmanager.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="https://tags.crwdcntrl.net" rel="preconnect"/>
#   <link href="https://bcp.crwdcntrl.net" rel="preconnect"/>
#   <link href="https://tags.crwdcntrl.net" rel="dns-prefetch"/>
#   <link href="https://bcp.crwdcntrl.net" rel="dns-prefetch"/>
#   <link as="style" href="https://assets.hmetro.com.my/assets/css/libraries.css?id=7979572225756f8aee4c" rel="preload"/>
#   <link as="style" href="https://assets.hmetro.com.my/assets/css/desktop/app.css?id=e376b753c5b2f5388b00" rel="preload"/>
# ...

# %%
body = soup.find_all('article-component')

type(body)
# Out:
# bs4.element.ResultSet

# %%
import re

list = []

for x in body:
    list.append(str(x))
    
# print(list[0])

re.search(r"\{.*\}", str(body)).group(0)
# Out:
# "{&quot;nid&quot;:1129405,&quot;title&quot;:&quot;'Isteri dan emak sudah nyawa-nyawa ikan ketika cuba diselamatkan'&quot;,&quot;created&quot;:1725178058,&quot;changed&quot;:1725211135,&quot;sponsored&quot;:0,&quot;status&quot;:1,&quot;url&quot;:&quot;https:\\/\\/www.hmetro.com.my\\/utama\\/2024\\/09\\/1129405\\/isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatkan&quot;,&quot;internal_url&quot;:&quot;\\/utama\\/2024\\/09\\/1129405\\/isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatkan&quot;,&quot;emotion&quot;:&quot;anger&quot;,&quot;segment&quot;:&quot;others&quot;,&quot;sentiment&quot;:&quot;negative&quot;,&quot;field_force_ads&quot;:[],&quot;field_article_author&quot;:{&quot;tid&quot;:3648,&quot;name&quot;:&quot;Zuliaty Zulkiffli&quot;,&quot;email&quot;:null,&quot;photo&quot;:null,&quot;internal_url&quot;:&quot;\\/authors\\/zuliaty-zulkiffli&quot;},&quot;field_author_email&quot;:&quot;am@hmetro.com.my&quot;,&quot;field_article_authors&quot;:[{&quot;tid&quot;:3
# ...

# %%
import html

string = r"{&quot;nid&quot;:1129405,&quot;title&quot;:&quot;'Isteri dan emak sudah nyawa-nyawa ikan ketika cuba diselamatkan'&quot;,&quot;created&quot;:1725178058,&quot;changed&quot;:1725178058,&quot;sponsored&quot;:0,&quot;status&quot;:1,&quot;url&quot;:&quot;https:\/\/www.hmetro.com.my\/utama\/2024\/09\/1129405\/isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatkan&quot;,&quot;internal_url&quot;:&quot;\/utama\/2024\/09\/1129405\/isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatk
isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatkan","emotion":null,"segment":null,"sentiment":null,"field_force_ads":[],"field_article_author":{"tid":3648,"name":"Zuliaty Zulkiffli","email":null,"photo":null,"internal_url":"\\/authors\\/zuliaty-zulkiffli"},"field_author_email":"am@hmetro.com.my","field_article_authors":[{"tid":3648,"name":"Zuliaty Zulkiffli","email":null,"photo":null,"internal_url":"\\/authors\\/zuliaty-zulkiffli"}],"field_article_topic":{"tid":169,"name":"Utama"},"field_tags":[{"tid":5040,"name":"kemalangan","auto_generated":false},{"tid":4568,"name":"kedah","auto_generated":false},{"tid":1906,"name":"Mata","auto_ge
# ...

# %%
import json

json_string = json.loads(string_parsed_html)

json_string['body']
# Out:
# 'am@hmetro.com.my<p /><p>Sungai Petani: "Sejurus kemalangan berlaku, saya dapati anak bongsu, isteri dan emak \'hilang\' dan saya cuba mencari mereka dalam kereta tetapi tiada.</p><p /><p>"Ketika itu hanya anak sulung, Luth Mikhael, 3, berada di bahagian belakang kereta. Tidak lama kemudian, ada penduduk kampung datang membawa anak,<a href="https://www.hmetro.com.my/mutakhir/2024/09/1129277/elak-kera-melintas-dua-beranak-maut-kemalangan"> Lufiya Mikhayla, </a>2, sambil memberitahu isteri dan emak tercampak keluar dari kereta," kata Mohd Fadzil Othman, 27.,</p><p /><p>Menurutnya, dia kemudian bergegas mendapatkan isterinya, Siti Norhasliza Kamarudin, 26, yang tercampak beberapa meter dari kereta yang ketika itu dalam keadaan nyawa-nyawa ikan.</p><p /><p>Katanya, dia juga sempat mengajar isterinya mengucap dua kalimah syahadah sebelum arwah menghembuskan nafas terakhirnya.</p><p /><p>"Saya kemudian mendapatkan emak, Omi Kalsom Man, 69, yang ketika itu dalam keadaan sama, sangat nazak s
# ...

# %%
from bs4 import BeautifulSoup
import html
import json
import re

article_url = "https://www.hmetro.com.my/utama/2024/09/1129405/isteri-dan-emak-sudah-nyawa-nyawa-ikan-ketika-cuba-diselamatkan"

response = requests.get(article_url)

soup = BeautifulSoup(response.text, 'html.parser')
body = soup.find_all('article-component')

string = re.search(r"\{.*\}", str(body)).group(0)
    
string_parsed_html = html.unescape(string)


json_string = json.loads(string_parsed_html)

json_string['body']
# Out:
# 'am@hmetro.com.my<p /><p>Sungai Petani: "Sejurus kemalangan berlaku, saya dapati anak bongsu, isteri dan emak \'hilang\' dan saya cuba mencari mereka dalam kereta tetapi tiada.</p><p /><p>"Ketika itu hanya anak sulung, Luth Mikhael, 3, berada di bahagian belakang kereta. Tidak lama kemudian, ada penduduk kampung datang membawa anak,<a href="https://www.hmetro.com.my/mutakhir/2024/09/1129277/elak-kera-melintas-dua-beranak-maut-kemalangan"> Lufiya Mikhayla, </a>2, sambil memberitahu isteri dan emak tercampak keluar dari kereta," kata Mohd Fadzil Othman, 27.,</p><p /><p>Menurutnya, dia kemudian bergegas mendapatkan isterinya, Siti Norhasliza Kamarudin, 26, yang tercampak beberapa meter dari kereta yang ketika itu dalam keadaan nyawa-nyawa ikan.</p><p /><p>Katanya, dia juga sempat mengajar isterinya mengucap dua kalimah syahadah sebelum arwah menghembuskan nafas terakhirnya.</p><p /><p>"Saya kemudian mendapatkan emak, Omi Kalsom Man, 69, yang ketika itu dalam keadaan sama, sangat nazak s
# ...

# %% [markdown]
# # Add new column to the dataframe

# %%
df = pd.read_csv("../data/hmetro_articles_without_body.csv")

# %%
def get_body(url):
    article_url = f"https://www.hmetro.com.my/{url}"
    response = requests.get(article_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    body = soup.find_all('article-component')
    string = re.search(r"\{.*\}", str(body)).group(0)
    string_parsed_html = html.unescape(string)
    json_string = json.loads(string_parsed_html)
    return json_string['body']

# %%
df['body'] = df['url'].apply(get_body)
df
# Out:
#                                                                         title  \
# 0           'Isteri dan emak sudah nyawa-nyawa ikan ketika cuba diselamatkan'
# 1                                    'Bukan cari hantu, bongkar lokasi keras'
# 2                                                Penglipur lara cerita seram!
# 3                 Tang Jie-Ee Wei cipta sejarah peribadi, juara Terbuka Korea
# 4                                            Membesar dengan lagu Raja Gambus
# ..                                                                        ...
# 195  Suspek tikam dua wanita di tandas surau di Kelana Jaya ditahan di Kajang
# 196                                          Hasil gubahan pencipta tiga kaum
# 197                                                    Cabaran 'Ustaz Jazlan'
# 198                                  Lelaki didakwa bunuh anak tauke restoran
# 199       Suspek bukan bekas teman lelaki arwah - suami Allahyarham Istiqomah
#
# ...

# %%
df.sample(5)
# Out:
#                                                                                       title  \
# 41                                     Nik Nazmi, Fahmi tarik diri bertanding Presiden KLFA
# 5                                                                  Israel buru Yahya Sinwar
# 162  Setahun tragedi pesawat terhempas di Elmina: Bapa sering terbayang wajah Muhamad Hafiz
# 172                                    Ibu bersyukur Afham ditemukan dalam keadaan sempurna
# 70                                                             PPR bukan untuk miskin tegar
#
#                                                                                                                          url  \
# 41                       https://www.hmetro.com.my/utama/2024/08/1127944/nik-nazmi-fahmi-tarik-diri-bertanding-presiden-klfa
# 5                                                   https://www.hmetro.com.my/utama/2024/09/1129217/israel-buru-yahya-sinwar
# ...

# %%
df.assign( body = df.body.str.replace(r'<\/?[a-zA-Z][^>]*>|(©.*Bhd)|(^[\w\d@.]*.my)', '', regex=True).str.strip())
# Out:
#                                                                         title  \
# 0           'Isteri dan emak sudah nyawa-nyawa ikan ketika cuba diselamatkan'
# 1                                    'Bukan cari hantu, bongkar lokasi keras'
# 2                                                Penglipur lara cerita seram!
# 3                 Tang Jie-Ee Wei cipta sejarah peribadi, juara Terbuka Korea
# 4                                            Membesar dengan lagu Raja Gambus
# ..                                                                        ...
# 195  Suspek tikam dua wanita di tandas surau di Kelana Jaya ditahan di Kajang
# 196                                          Hasil gubahan pencipta tiga kaum
# 197                                                    Cabaran 'Ustaz Jazlan'
# 198                                  Lelaki didakwa bunuh anak tauke restoran
# 199       Suspek bukan bekas teman lelaki arwah - suami Allahyarham Istiqomah
#
# ...
